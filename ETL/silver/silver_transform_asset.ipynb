# %% [markdown]
# # IMPORT REQUIRED LIBRARIES

# %%
from pyspark.sql.functions import trim, col, to_date
from pyspark.sql.types import StringType
from pyspark.sql.types import DateType

# %% [markdown]
# # READ FROM BRONZE DELTA TABLE

# %%
df = spark.table("fm_prj1.bronze.assets")

# %% [markdown]
# # TRANSFORMATIONS

# %% [markdown]
# ## TRIM - STRING COLUMNS

# %%
for field in df.schema.fields:
    if isinstance(field.dataType, StringType):
        df = df.withColumn(
            field.name,
            trim(
                col(field.name)
            )
        )

# %% [markdown]
# ## DROP DUPLICATES AND EMPTY ROWS

# %%
df.dropDuplicates()
df.dropna(how="all")

# %% [markdown]
# ## TYPE CASTING

# %%
df = df.withColumn(
    "install_date",
    col("install_date").cast(DateType())
)

# %% [markdown]
# # WRITE TO SILVER DELTA TABLE

# %%
print("Writing to silver delta table...")
(
    df.write
        .format("delta")
        .mode("overwrite")
        .saveAsTable("fm_prj1.silver.asset")
)
print("Succesfully completed writing to silver delta table")
